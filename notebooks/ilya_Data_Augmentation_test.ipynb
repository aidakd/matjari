# %%
import PIL
import numpy as np
import pandas as pd
import sklearn

# %%
from PIL import Image
from numpy import asarray

# %%
full_df = pd.read_pickle('../raw_data/full_dataset.pkl')

# %%
full_df.head()
# Out:
#   Product Label                                                url        key  \
# 0           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000122
# 1           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000123
# 2           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000133
# 3           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000134
# 4           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000135
#
#                                                    X
# 0  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 1  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 2  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 3  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 4  [[[255, 255, 255], [255, 255, 255], [255, 255,...

# %%
import matplotlib.pyplot as plt
import cv2
import os
import tensorflow as tf
# Out:
# 2022-07-02 15:27:12.886677: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/ilya/.pyenv/versions/3.8.12/envs/matjari/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-07-02 15:27:12.887457: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from matplotlib import pyplot as plt

X = full_df['X']
plt.imshow(X[100], interpolation='nearest')
plt.show()

# %%
import numpy as np
import pandas as pd
import PIL

# %%
from PIL import Image
from numpy import asarray

# %%
full_df.head()
# Out:
#   Product Label                                                url        key  \
# 0           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000122
# 1           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000123
# 2           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000133
# 3           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000134
# 4           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000135
#
#                                                    X
# 0  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 1  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 2  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 3  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 4  [[[255, 255, 255], [255, 255, 255], [255, 255,...

# %%
full_df['X'][0]
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
#X = full_df['X']

#for i in range(0,len(full_df)):
    #img = Image.open(X[i])
    #img
#for image in images:
 #   img = cv2.imread(str(image))
  #  resized_img = cv2.resize(img(180,180))
   # X.append(resized_img)
    #y.append(img['Product Label'])

# %%
img = cv2.imread(str(full_df['X'][0]))
# Out:
# [ WARN:0@42.947] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('[[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]'): can't open/read file: check file path/integrity

# %%
full_df['X'][0].shape
# Out:
# (256, 256, 3)

# %%
cv2.resize(full_df['X'][0],(180,180)).shape
# Out:
# (180, 180, 3)

# %%
X_full_resized = []

for i in range (0,len(full_df)):
    X_full_resized.append(cv2.resize(full_df['X'][i],(180,180)))

# %%
tmp = pd.DataFrame({'Resized_X':X_full_resized})
tmp
# Out:
#                                                Resized_X
# 0      [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 1      [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 2      [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 3      [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 4      [[[255, 255, 255], [255, 255, 255], [255, 255,...
# ...                                                  ...
# 12840  [[[251, 252, 254], [251, 252, 254], [251, 252,...
# 12841  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 12842  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 12843  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 12844  [[[255, 255, 255], [255, 255, 255], [255, 255,...
#
# [12845 rows x 1 columns]

# %%
full_df_new = pd.concat([full_df, tmp], axis=1)

# %%
full_df_new.to_pickle('resized_full_df.pkl')

# %%
full_df_new.loc[0, 'Resized_X'].shape
# Out:
# (180, 180, 3)

# %%
X_full_resized[6].shape
# Out:
# (180, 180, 3)

# %%
from matplotlib import pyplot as plt

plt.imshow(X[0], interpolation='nearest')
plt.show()

# %%
img = Image.fromarray(X[0], 'RGB')
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
data_augmentation=keras.Sequential([ layers.experimental.preprocessing.RandomZoom(0.5),])

plt.imshow(data_augmentation(X[0]).numpy().astype('uint8'))
# Out:
# 2022-07-02 15:33:27.692753: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/ilya/.pyenv/versions/3.8.12/envs/matjari/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-07-02 15:33:27.721559: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-07-02 15:33:27.759053: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (DESKTOP-0T43TK7): /proc/driver/nvidia/version does not exist
# 2022-07-02 15:33:27.883994: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# ...

# %%
data_augmentation_contrast=keras.Sequential([ layers.experimental.preprocessing.RandomContrast(0.9), ])

plt.imshow(data_augmentation_contrast(X[0]).numpy().astype('uint8'))

# %%
import imageio
import imgaug as ia
import imgaug.augmenters as iaa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib
# %matplotlib inline

photo= imageio.imread('../raw_data/ALL Pictures/ALL Pictures/000000032.jpg')
ia.imshow(photo)
# Out:
# /tmp/ipykernel_27192/1138179540.py:11: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   photo= imageio.imread('../raw_data/ALL Pictures/ALL Pictures/000000032.jpg')

# %%
rotate=iaa.Affine(rotate=(-50, 30))
rotated_photo=rotate.augment_image(photo)
ia.imshow(rotated_photo)

#flipping image horizontally
flip_hr=iaa.Fliplr(p=1.0)
flip_hr_photo=flip_hr.augment_image(photo)
ia.imshow(flip_hr_photo)

flip_vr=iaa.Flipud(p=1.0)
flip_vr_photo= flip_vr.augment_image(photo)
ia.imshow(flip_vr_photo)

# %%
for i in range(0,2):
    photo= imageio.imread(f'../raw_data/ALL Pictures/ALL Pictures/', str('00000000'+{i}) +'.jpg'
    ia.imshow(photo)
# Out:
#   Input In [51]
#     ia.imshow(photo)
#     ^
# SyntaxError: invalid syntax

# %%
import imageio
import imgaug as ia
import imgaug.augmenters as iaa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib
# %matplotlib inline


for i in range(0,2):
    photo= imageio.imread('../raw_data/ALL Pictures/ALL Pictures/[i].jpg') 
    
    rotate=iaa.Affine(rotate=(-50, 30))
    rotated_photo=rotate.augment_image(photo)
    ia.imshow(rotated_photo)

#flipping image horizontally
    flip_hr=iaa.Fliplr(p=1.0)
    flip_hr_photo=flip_hr.augment_image(photo)
    ia.imshow(flip_hr_photo)

    flip_vr=iaa.Flipud(p=1.0)
    flip_vr_photo= flip_vr.augment_image(photo)
    ia.imshow(flip_vr_photo)
# Out:
#   Input In [28]
#     for i in range(0,len(full_df_new))
#                                       ^
# SyntaxError: invalid syntax

# %%
from sklearn.model_selection import train_test_split

X = full_df_new['X']
y = full_df_new['Product Label']
X_train = np.array(X)
y_train = np.array(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)
X_train_scaled = X_train/255
X_test_scaled = X_test/255

# %%
num_classes = 10
model =Sequential([
    layers.Conv2D(16,3, padding='same', activation = 'relu')
    layers.MaxPooling2D(),
    layers.Conv2D(32,3, padding='same', activation = 'relu')
    layers.MaxPooling2D(),
    layers.Conv2D(64,3, padding='same', activation = 'relu')
    layers.MaxPooling2D(),
    layers.Flatten(),
        layers.Dense(128, activation= 'relu'),
        layers.Dense(num_classes)
])

# %%
model.compile(optimizer= 'adam', loss= tf.keras.sparseCategoricalCrossentropy(from_logists= True), metrics=['accuracy'])
model.fit(X_train_scaled, y_train, epochs =30)

# %%
model.evaluate(X_test.scaled, y_test)
predictions = model.predict(X_test_scaled)
predictions

# %%
score = tf.nn.softMax(predictions[])
score

# %%
data_augmentation=keras.Sequential([ layers.experimental.preprocessing.RandomContrast(0.9),
                                     layers.experimental.preprocessing.RandomZoom(0.8),])
