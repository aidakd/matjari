# %% [markdown]
# ## Testing the python package locally before moving to cloud

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from matjari.load_data import get_data, load_json, load_img, load_nrows, encod, split_data
data = get_data()
data = load_json(data)
data = load_img(data)
data = load_nrows(data)

# %%
data
# Out:
#       Product Label                                                url  \
# 1208            Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 8375            Rug  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 6563       Necklace  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 6937           Pouf  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 6647         Poster  https://cdn.shopify.com/s/files/1/0050/7478/02...
# ...             ...                                                ...
# 8460            Rug  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 8024            Rug  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 8009            Rug  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 1728        Blanket  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 10215         Shoes  https://cdn.shopify.com/s/files/1/0050/7478/02...
#
#              key   status error_message  width  height  original_width  \
# 1208   000001415  success          None    256     256            1440
# 8375   000009210  success          None    256     256            1172
# 6563   000005862  success          None    256     256            1149
# 6937   000007565  success          None    256     256            3751
# 6647   000002067  success          None    256     256            2058
# ...          ...      ...           ...    ...     ...             ...
# 8460   000009295  success          None    256     256             856
# 8024   000008859  success          None    256     256             780
# 8009   000008844  success          None    256     256            1040
# 1728   000001651  success          None    256     256            1000
# 10215  000009673  success          None    256     256            2009
#
#        original_height                                               exif  \
# 1208              1440  {"Image Orientation": "Horizontal (normal)", "...
# 8375              1172                 {"Image HostComputer": "imagery4"}
# 6563              1150                 {"Image HostComputer": "imagery4"}
# 6937              3751                                                 {}
# 6647              2058  {"Image Orientation": "Horizontal (normal)", "...
# ...                ...                                                ...
# 8460               856                 {"Image HostComputer": "imagery4"}
# 8024               975                 {"Image HostComputer": "imagery4"}
# 8009               780                 {"Image HostComputer": "imagery4"}
# 1728              1000                 {"Image HostComputer": "imagery4"}
# 10215             2009  {"Image Orientation": "Horizontal (normal)", "...
#
#                                     md5  \
# 1208   2866dd5284383420afaab6ab75ebbc8a
# 8375   549b0d25914f4b6441c1f172ce145ab8
# 6563   39e21571ca2e0c9faf61709372bff993
# 6937   f2634f0bbe6aa541b7fde9710ea0c688
# 6647   e16ee21943af09a233a15d3335b5060e
# ...                                 ...
# 8460   7c9caf72249215810304cc6f7c19500c
# 8024   83c1dc5f70afc454aa035bf603bb7aa5
# 8009   a4f7046f9918fc5690e62a5b3f3ab7bb
# 1728   8299c983e4f131cf8b6b4db34dac3d02
# 10215  52338194b86cddd2484950c953a8fb5d
#
#                                                        A
# 1208   [[[254, 254, 254], [254, 254, 254], [254, 254,...
# 8375   [[[5, 27, 138], [3, 25, 136], [3, 25, 136], [4...
# 6563   [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 6937   [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 6647   [[[255, 255, 255], [255, 255, 255], [255, 255,...
# ...                                                  ...
# 8460   [[[170, 218, 240], [169, 217, 237], [165, 210,...
# 8024   [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 8009   [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 1728   [[[176, 177, 169], [177, 178, 170], [177, 178,...
# 10215  [[[255, 255, 255], [255, 255, 255], [255, 255,...
#
# [100 rows x 12 columns]

# %%
X, y = encod(data)

# %%
X_train, X_test, y_train, y_test = split_data(X, y)

# %%
from matjari.trainer import Trainer
trainer = Trainer(model)
model = trainer.get_model()

# %%
model

# %%
history = trainer.fit()
# Out:
# Epoch 1/100
# 4/4 - 9s - loss: 3.3475 - accuracy: 0.0816 - val_loss: 3.3203 - val_accuracy: 0.0952 - 9s/epoch - 2s/step
# Epoch 2/100
# 4/4 - 7s - loss: 3.1870 - accuracy: 0.1429 - val_loss: 3.3342 - val_accuracy: 0.0952 - 7s/epoch - 2s/step
# Epoch 3/100
# 4/4 - 7s - loss: 3.0510 - accuracy: 0.1837 - val_loss: 3.3806 - val_accuracy: 0.1429 - 7s/epoch - 2s/step
# Epoch 4/100
# 4/4 - 7s - loss: 2.9412 - accuracy: 0.3061 - val_loss: 3.4059 - val_accuracy: 0.1905 - 7s/epoch - 2s/step
# Epoch 5/100
# 4/4 - 8s - loss: 2.8741 - accuracy: 0.2449 - val_loss: 3.4720 - val_accuracy: 0.1905 - 8s/epoch - 2s/step
# Epoch 6/100
# 4/4 - 8s - loss: 2.8341 - accuracy: 0.2449 - val_loss: 3.6426 - val_accuracy: 0.1429 - 8s/epoch - 2s/step
# Epoch 7/100
# 4/4 - 9s - loss: 2.8187 - accuracy: 0.2245 - val_loss: 3.7692 - val_accuracy: 0.1429 - 9s/epoch - 2s/step
# Epoch 8/100
# 4/4 - 10s - loss: 2.7533 - accuracy: 0.2245 - val_loss: 3.6498 - val_accuracy: 0.0952 - 10s/epoch - 2s/step
# Epoch 9/100
# 4/4 - 10s - loss: 2.7044 - accuracy: 0.2245 - val_loss: 3.6251 - val_accuracy: 0.1429 - 10s/epoch - 3s/step
# Epoch 10/100
# 4/4 - 9s - loss: 2.6843 - accuracy: 0.1837 - val_loss: 3.6738 - val_accuracy: 0.1429 - 9s/epoch - 2s/step
# Epoch 11/100
# 4/4 - 8s - loss: 2.6540 - accuracy: 0.1429 - val_loss: 3.7248 - val_accuracy: 0.1429 - 8s/epoch - 2s/step
# Epoch 12/100
# 4/4 - 7s - loss: 2.6429 - accuracy: 0.1429 - val_loss: 3.7978 - val_accuracy: 0.1429 - 7s/epoch - 2s/step
# Epoch 13/100
# 4/4 - 7s - loss: 2.5671 - accuracy: 0.1633 - val_loss: 3.7259 - val_accuracy: 0.0952 - 7s/epoch - 2s/step
# Epoch 14/100
# 4/4 - 7s - loss: 2.5165 - accuracy: 0.2449 - val_loss: 3.8157 - val_accuracy: 0.1429 - 7s/epoch - 2s/step
# Epoch 15/100
# 4/4 - 7s - loss: 2.4470 - accuracy: 0.2449 - val_loss: 3.9163 - val_accuracy: 0.0476 - 7s/epoch - 2s/step
# Epoch 16/100
# 4/4 - 7s - loss: 2.3912 - accuracy: 0.2653 - val_loss: 4.0983 - val_accuracy: 0.0952 - 7s/epoch - 2s/step
# Epoch 17/100
# 4/4 - 7s - loss: 2.3359 - accuracy: 0.3878 - val_loss: 4.2640 - val_accuracy: 0.0952 - 7s/epoch - 2s/step
# Epoch 18/100
# 4/4 - 8s - loss: 2.2585 - accuracy: 0.3673 - val_loss: 4.4716 - val_accuracy: 0.0952 - 8s/epoch - 2s/step
# Epoch 19/100
# 4/4 - 8s - loss: 2.2155 - accuracy: 0.3469 - val_loss: 4.3604 - val_accuracy: 0.0952 - 8s/epoch - 2s/step
# Epoch 20/100
# 4/4 - 7s - loss: 2.1304 - accuracy: 0.3673 - val_loss: 4.3942 - val_accuracy: 0.1429 - 7s/epoch - 2s/step
# Epoch 21/100
# 4/4 - 7s - loss: 2.0360 - accuracy: 0.4490 - val_loss: 4.4079 - val_accuracy: 0.0476 - 7s/epoch - 2s/step

# %%
score = trainer.evaluate()
# Out:
# 1/1 - 1s - loss: 3.2426 - accuracy: 0.1000 - 976ms/epoch - 976ms/step

# %%
trainer.save_model()
# Out:
# 2022-07-02 11:35:52.346053: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: ram://c6789521-2186-4918-b5be-bc22f605bd60/assets
