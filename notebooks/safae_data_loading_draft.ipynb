# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../matjari/data/matjari-dataset-cleaned.csv', sep='\t')
df.columns = ['Product Label','url']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 df = pd.read_csv('../matjari/data/matjari-dataset-cleaned.csv', sep='\t')
#       2 df.columns = ['Product Label','url']
#
# File ~/.pyenv/versions/lewagon/envs/matjari/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/lewagon/envs/matjari/lib/python3.8/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/lewagon/envs/matjari/lib/python3.8/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/.pyenv/versions/lewagon/envs/matjari/lib/python3.8/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~/.pyenv/versions/lewagon/envs/matjari/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~/.pyenv/versions/lewagon/envs/matjari/lib/python3.8/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../matjari/data/matjari-dataset-cleaned.csv'

# %%
df
# Out:
#       Product Label                                                url
# 0               Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 1               Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 2               Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 3               Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 4               Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...
# ...             ...                                                ...
# 10714        Wallet  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 10715        Wallet  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 10716        Wallet  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 10717        Wallet  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 10718        Wallet  https://cdn.shopify.com/s/files/1/0050/7478/02...
#
# [10719 rows x 2 columns]

# %%
import os, json
import pandas as pd

path_to_json = "../raw_data/pictures-from-script/ALL Pictures"
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
print(json_files)  # for me this prints ['foo.json']
# Out:
# ['000012551.json', '000001687.json', '000006142.json', '000000995.json', '000004485.json', '000003340.json', '000010096.json', '000012101.json', '000006512.json', '000003710.json', '000002802.json', '000007753.json', '000000096.json', '000006841.json', '000002551.json', '000005294.json', '000010995.json', '000011687.json', '000012802.json', '000007303.json', '000002101.json', '000000429.json', '000002414.json', '000008019.json', '000011238.json', '000007616.json', '000006904.json', '000004939.json', '000005781.json', '000000079.json', '000002044.json', '000004893.json', '000011392.json', '000008449.json', '000012947.json', '000011668.json', '000000583.json', '000007246.json', '000003205.json', '000001238.json', '000009608.json', '000010429.json', '000012414.json', '000006007.json', '000003655.json', '000004190.json', '000001668.json', '000002947.json', '000010583.json', '000009258.json', '000010079.json', '000012044.json', '000006457.json', '000001392.json', '000009872.json', '000008760.json', '000000350.json', '000007495.json', '000003985.json', '000005152.json', '000002697.json', '000011541.json', '000008330.json', '000001812.json', '000000700.json', '000005502.json', '000011111.json', '000012697.json', '000009171.json', '000006284.json', '000001541.json', '000005851.json', '000003086.json', '000004743.json', '000010350.json', '000009521.json', '000001111.json', '000004313.json', '000010700.json', '000011812.json', '000007929.json', '000005914.json', '000004606.json', '000012228.json', '000010215.json', '000009034.json', '000001404.json', '000003439.json', '000004256.json', '000003593.json', '000012678.json', '000010645.json', '000011957.json', '000009464.json', '000012382.json', '000007883.json', '000001054.json', '000003069.json', '000006791.json', '000005017.json', '000011404.json', '000009937.json', '000008625.json', '000002228.json', '000000215.json', '000002382.json', '000005447.json', '000011054.json', '000008275.json', '000001957.json', '000002678.json', '000007180.json', '000000645.json', '000005693.json', '000002156.json', '000004981.json', '000011280.json', '000010868.json', '000012855.json', '000000491.json', '000005369.json', '000007354.json', '000002506.json', '000005739.json', '000007704.json', '000006816.json', '000003747.json', '000004082.json', '000000868.json', '000002855.json', '000010491.json', '000012156.json', '000006545.json', '000001280.json', '000004578.json', '000003317.json', '000008808.json', '000012506.json', '000006115.json', '000004128.json', '000012013.json', '000006400.json', '000003602.json', '000002910.json', '000012443.json', '000001795.json', '000006050.json', '000000887.json', '000004597.json', '000003252.json', '000010184.json', '000012910.json', '000007211.json', '000002013.json', '000007641.json', '000000184.json', '000006953.json', '000002443.json', '000005386.json', '000010887.json', '000011795.json', '000004344.json', '000006379.json', '000003481.json', '000010757.json', '000011845.json', '000009576.json', '000007991.json', '000001146.json', '000006683.json', '000005806.json', '000004714.json', '000006729.json', '000010307.json', '000009126.json', '000001516.json', '000007568.json', '000002290.json', '000005555.json', '000011146.json', '000008367.json', '000001845.json', '000003878.json', '000007092.json', '000000757.json', '000007138.json', '000005105.json', '000011516.json', '000009825.json', '000008737.json', '000000307.json', '000008222.json', '000001900.json', '000000612.json', '000005410.json', '000011003.json', '000009960.json', '000008672.json', '000007587.json', '000003897.json', '000005040.json', '000002785.json', '000008388.json', '000011453.json', '000009433.json', '000001003.json', '000004201.json', '000010612.json', '000011900.json', '000012785.json', '000009063.json', '000006396.json', '000001453.json', '000005943.json', '000003194.json', '000004651.json', '000009599.json', '000010242.json', '000006103.json', '000012510.json', '000003301.json', '000006553.json', '00 ...

# %%
jsons_data = pd.DataFrame(columns=["url", "key", "status", "error_message", "width", "height", "original_width", "original_height", "exif", "md5"])

# %%
for index, js in enumerate(json_files):
    with open(os.path.join(path_to_json, js)) as json_file:
        json_text = json.load(json_file)

        # here you need to know the layout of your json and each json has to have
        # the same structure (obviously not the structure I have here)
        url = json_text["url"]
        key = json_text["key"]
        status = json_text["status"]
        error_message = json_text["error_message"]
        width = json_text["width"]
        height = json_text["height"]
        original_width = json_text["original_width"]
        original_height = json_text["original_height"]
        exif = json_text["exif"]
        md5 = json_text["md5"]
        # here I push a list of data into a pandas DataFrame at row given by 'index'
        jsons_data.loc[index] = [url, key, status, error_message, width, height, original_width, original_height, exif, md5]

# now that we have the pertinent json data in our DataFrame let's look at it
print(jsons_data)
# Out:
#                                                      url        key   status  \
# 0      https://cdn.shopify.com/s/files/1/0050/7478/02...  000012551  success
# 1      https://cdn.shopify.com/s/files/1/0050/7478/02...  000001687  success
# 2      https://cdn.shopify.com/s/files/1/0050/7478/02...  000006142  success
# 3      https://cdn.shopify.com/s/files/1/0050/7478/02...  000000995  success
# 4      https://cdn.shopify.com/s/files/1/0050/7478/02...  000004485  success
# ...                                                  ...        ...      ...
# 12876  https://cdn.shopify.com/s/files/1/0050/7478/02...  000011885  success
# 12877  https://cdn.shopify.com/s/files/1/0050/7478/02...  000010797  success
# 12878  https://cdn.shopify.com/s/files/1/0050/7478/02...  000012600  success
# 12879  https://cdn.shopify.com/s/files/1/0050/7478/02...  000006213  success
# 12880  https://cdn.shopify.com/s/files/1/0050/7478/02...  000003011  success
#
#       error_message  width  height  original_width  original_height  \
# 0              None    256     256             980              980
# 1              None    256     256             736              736
# 2              None    256     256            3166             3166
# 3              None    256     256            3024             3024
# 4              None    256     256            1080              909
# ...             ...    ...     ...             ...              ...
# 12876          None    256     256            1080             1080
# 12877          None    256     256            2724             2724
# 12878          None    256     256             960             1280
# 12879          None    256     256            2621             3931
# 12880          None    256     256            1024             1024
#
#                                                     exif  \
# 0      {"Image Orientation": "Horizontal (normal)", "...
# 1                     {"Image HostComputer": "imagery4"}
# 2      {"Image Orientation": "Horizontal (normal)", "...
# 3                     {"Image HostComputer": "imagery4"}
# 4                                                     {}
# ...                                                  ...
# 12876                 {"Image HostComputer": "imagery4"}
# 12877                                                 {}
# 12878                 {"Image HostComputer": "imagery4"}
# 12879  {"Image Orientation": "Horizontal (normal)", "...
# 12880                 {"Image HostComputer": "imagery4"}
#
#                                     md5
# 0      4372720c68fc00cab313a02fda544caf
# 1      992d3a4ab9dc0d8e62813cb7718f7aa2
# 2      b178b7dda33b896951dc897fa475da58
# 3      b9a9238ac262c15704b45c39ae967c66
# 4      71be8453e6a4f537061951980ffd0a39
# ...                                 ...
# 12876  13ffec19cfbd045c01771b426fbfc335
# 12877  927bfa06f4b71696363cfcb532c4ef3e
# 12878  87ea7b24f65ef1b6788c42f46e96e6f6
# 12879  72f81efedb8c6a78b66159be8e9f5fcc
# 12880  04bd90b92a6f0592481b0b0eab838c12
#
# [12881 rows x 10 columns]

# %%
df2 = pd.DataFrame(jsons_data)
df2
# Out:
#                                                      url        key   status  \
# 0      https://cdn.shopify.com/s/files/1/0050/7478/02...  000012551  success
# 1      https://cdn.shopify.com/s/files/1/0050/7478/02...  000001687  success
# 2      https://cdn.shopify.com/s/files/1/0050/7478/02...  000006142  success
# 3      https://cdn.shopify.com/s/files/1/0050/7478/02...  000000995  success
# 4      https://cdn.shopify.com/s/files/1/0050/7478/02...  000004485  success
# ...                                                  ...        ...      ...
# 12876  https://cdn.shopify.com/s/files/1/0050/7478/02...  000011885  success
# 12877  https://cdn.shopify.com/s/files/1/0050/7478/02...  000010797  success
# 12878  https://cdn.shopify.com/s/files/1/0050/7478/02...  000012600  success
# 12879  https://cdn.shopify.com/s/files/1/0050/7478/02...  000006213  success
# 12880  https://cdn.shopify.com/s/files/1/0050/7478/02...  000003011  success
#
#       error_message  width  height  original_width  original_height  \
# 0              None    256     256             980              980
# 1              None    256     256             736              736
# 2              None    256     256            3166             3166
# 3              None    256     256            3024             3024
# 4              None    256     256            1080              909
# ...             ...    ...     ...             ...              ...
# 12876          None    256     256            1080             1080
# 12877          None    256     256            2724             2724
# 12878          None    256     256             960             1280
# 12879          None    256     256            2621             3931
# 12880          None    256     256            1024             1024
#
#                                                     exif  \
# 0      {"Image Orientation": "Horizontal (normal)", "...
# 1                     {"Image HostComputer": "imagery4"}
# 2      {"Image Orientation": "Horizontal (normal)", "...
# 3                     {"Image HostComputer": "imagery4"}
# 4                                                     {}
# ...                                                  ...
# 12876                 {"Image HostComputer": "imagery4"}
# 12877                                                 {}
# 12878                 {"Image HostComputer": "imagery4"}
# 12879  {"Image Orientation": "Horizontal (normal)", "...
# 12880                 {"Image HostComputer": "imagery4"}
#
#                                     md5
# 0      4372720c68fc00cab313a02fda544caf
# 1      992d3a4ab9dc0d8e62813cb7718f7aa2
# 2      b178b7dda33b896951dc897fa475da58
# 3      b9a9238ac262c15704b45c39ae967c66
# 4      71be8453e6a4f537061951980ffd0a39
# ...                                 ...
# 12876  13ffec19cfbd045c01771b426fbfc335
# 12877  927bfa06f4b71696363cfcb532c4ef3e
# 12878  87ea7b24f65ef1b6788c42f46e96e6f6
# 12879  72f81efedb8c6a78b66159be8e9f5fcc
# 12880  04bd90b92a6f0592481b0b0eab838c12
#
# [12881 rows x 10 columns]

# %%
df_merge = df.merge(df2, how='inner', on='url')

# %%
df_merge
# Out:
#       Product Label                                                url  \
# 0               Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 1               Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 2               Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 3               Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 4               Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...
# ...             ...                                                ...
# 12840        Wallet  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 12841        Wallet  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 12842        Wallet  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 12843        Wallet  https://cdn.shopify.com/s/files/1/0050/7478/02...
# 12844        Wallet  https://cdn.shopify.com/s/files/1/0050/7478/02...
#
#              key   status error_message  width  height  original_width  \
# 0      000000122  success          None    256     256            2635
# 1      000000123  success          None    256     256            2955
# 2      000000133  success          None    256     256            1280
# 3      000000134  success          None    256     256             960
# 4      000000135  success          None    256     256             960
# ...          ...      ...           ...    ...     ...             ...
# 12840  000000164  success          None    256     256            1083
# 12841  000008498  success          None    256     256             768
# 12842  000008499  success          None    256     256             454
# 12843  000008500  success          None    256     256             727
# 12844  000008501  success          None    256     256             526
#
#        original_height                                exif  \
# 0                 2635  {"Image HostComputer": "imagery4"}
# 1                 2955  {"Image HostComputer": "imagery4"}
# 2                 1280  {"Image HostComputer": "imagery4"}
# 3                 1280  {"Image HostComputer": "imagery4"}
# 4                  960  {"Image HostComputer": "imagery4"}
# ...                ...                                 ...
# 12840             1083  {"Image HostComputer": "imagery4"}
# 12841              769  {"Image HostComputer": "imagery4"}
# 12842              454  {"Image HostComputer": "imagery4"}
# 12843              726  {"Image HostComputer": "imagery4"}
# 12844              526  {"Image HostComputer": "imagery4"}
#
#                                     md5
# 0      fec4543742d91ac05bfeba542ddd56a0
# 1      0fb2b60db41b798608302f23d2283415
# 2      517d74b620b8cbd2b558deffed97552e
# 3      d195b0f6a2c393c1df0f1c2b677045ed
# 4      bac44b98f1b11d427b150b770c0e18ef
# ...                                 ...
# 12840  f137cd70c01109331de820c4c15e6ef2
# 12841  506d4f3f4afa27db5a5941f718260b52
# 12842  b233348b580065e922b003e40ae3b49f
# 12843  ab20936b6e474e0c48652a0c0d07b810
# 12844  11484a24524132ce9cd75c3368ec030c
#
# [12845 rows x 11 columns]

# %%
from PIL import Image
import numpy as np
from numpy import asarray
X = []
for i in range(0, len(df_merge)):
    img = Image.open('../raw_data/pictures-from-script/ALL Pictures/' + str(df_merge['key'][i]) + '.jpg')
    img_array = asarray(img)
    X.append(img_array)

# %%
X[0].shape
# Out:
# (256, 256, 3)

# %%
X[0]
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
plt.imshow(X[0])

# %%
df_merge['X'] = X

# %%
df_merge['X'][0].shape
# Out:
# (256, 256, 3)

# %%
plt.imshow(df_merge['X'][12222])

# %%
df_merge['key'][12222]
# Out:
# '000012511'

# %%
img = Image.open('../raw_data/pictures-from-script/ALL Pictures/' + str(df_merge['key'][12222]) + '.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
df_merge.head(10)
# Out:
#   Product Label                                                url        key  \
# 0           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000122
# 1           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000123
# 2           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000133
# 3           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000134
# 4           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000135
# 5           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000136
# 6           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000137
# 7           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000138
# 8           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000177
# 9           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000178
#
#     status error_message  width  height  original_width  original_height  \
# 0  success          None    256     256            2635             2635
# 1  success          None    256     256            2955             2955
# 2  success          None    256     256            1280             1280
# 3  success          None    256     256             960             1280
# 4  success          None    256     256             960              960
# 5  success          None    256     256             500              500
# 6  success          None    256     256             960              960
# 7  success          None    256     256             960              960
# 8  success          None    256     256            2000             2000
# 9  success          None    256     256            2000             2000
#
#                                  exif                               md5  \
# 0  {"Image HostComputer": "imagery4"}  fec4543742d91ac05bfeba542ddd56a0
# 1  {"Image HostComputer": "imagery4"}  0fb2b60db41b798608302f23d2283415
# 2  {"Image HostComputer": "imagery4"}  517d74b620b8cbd2b558deffed97552e
# 3  {"Image HostComputer": "imagery4"}  d195b0f6a2c393c1df0f1c2b677045ed
# 4  {"Image HostComputer": "imagery4"}  bac44b98f1b11d427b150b770c0e18ef
# 5  {"Image HostComputer": "imagery4"}  fc6830524fc98b5fc263b162eb4ba4f9
# 6  {"Image HostComputer": "imagery4"}  492373dafb98dcaa0a1c26057d7a2a80
# 7  {"Image HostComputer": "imagery4"}  5df6f0df5d026979a4f6c22e5d0867e9
# 8  {"Image HostComputer": "imagery4"}  392b5af43cd2376b2edaa32f96d27a89
# 9  {"Image HostComputer": "imagery4"}  20b073c747b49ce2f04f0a200ed1284c
#
#                                                    X
# 0  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 1  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 2  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 3  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 4  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 5  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 6  [[[41, 152, 101], [41, 152, 101], [41, 152, 10...
# 7  [[[48, 162, 100], [48, 162, 100], [48, 162, 10...
# 8  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 9  [[[255, 255, 255], [255, 255, 255], [255, 255,...

# %%
df_merge.to_pickle('/Users/Safaemichelot/code/aidakd/matjari/raw_data/matjari_data_merged.pkl')

# %%
data_merge = pd.read_pickle('../raw_data/matjari_data_merged.pkl')

# %%
data_merge.head(10)
# Out:
#   Product Label                                                url        key  \
# 0           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000122
# 1           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000123
# 2           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000133
# 3           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000134
# 4           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000135
# 5           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000136
# 6           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000137
# 7           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000138
# 8           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000177
# 9           Bag  https://cdn.shopify.com/s/files/1/0050/7478/02...  000000178
#
#     status error_message  width  height  original_width  original_height  \
# 0  success          None    256     256            2635             2635
# 1  success          None    256     256            2955             2955
# 2  success          None    256     256            1280             1280
# 3  success          None    256     256             960             1280
# 4  success          None    256     256             960              960
# 5  success          None    256     256             500              500
# 6  success          None    256     256             960              960
# 7  success          None    256     256             960              960
# 8  success          None    256     256            2000             2000
# 9  success          None    256     256            2000             2000
#
#                                  exif                               md5  \
# 0  {"Image HostComputer": "imagery4"}  fec4543742d91ac05bfeba542ddd56a0
# 1  {"Image HostComputer": "imagery4"}  0fb2b60db41b798608302f23d2283415
# 2  {"Image HostComputer": "imagery4"}  517d74b620b8cbd2b558deffed97552e
# 3  {"Image HostComputer": "imagery4"}  d195b0f6a2c393c1df0f1c2b677045ed
# 4  {"Image HostComputer": "imagery4"}  bac44b98f1b11d427b150b770c0e18ef
# 5  {"Image HostComputer": "imagery4"}  fc6830524fc98b5fc263b162eb4ba4f9
# 6  {"Image HostComputer": "imagery4"}  492373dafb98dcaa0a1c26057d7a2a80
# 7  {"Image HostComputer": "imagery4"}  5df6f0df5d026979a4f6c22e5d0867e9
# 8  {"Image HostComputer": "imagery4"}  392b5af43cd2376b2edaa32f96d27a89
# 9  {"Image HostComputer": "imagery4"}  20b073c747b49ce2f04f0a200ed1284c
#
#                                                    X
# 0  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 1  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 2  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 3  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 4  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 5  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 6  [[[41, 152, 101], [41, 152, 101], [41, 152, 10...
# 7  [[[48, 162, 100], [48, 162, 100], [48, 162, 10...
# 8  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 9  [[[255, 255, 255], [255, 255, 255], [255, 255,...
